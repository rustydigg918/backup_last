# %% [markdown]
# # Principal Component Analysis- PCA

# %%
from IPython.display import Image
import os
os.chdir('E:\\SerotinousCones\\DSP17\\final')
print (os.getcwd())
# Out:
# E:\Imarticus\DSP17\final

# %%
# Some Business Situations:
#-------------------------#

# Let’s say we have a data set of dimension 300(n) × 50(p). 
# n = number of observations and p = number of predictors. 
# Since we have a large p = 50, there can be p(p-1)/2 scatter plots 
# i.e more than 1000 plots possible to analyze the variable relationship. 
# Wouldn’t it be a tedious job to perform exploratory analysis on this data ?

# What algorithm that you have learnt so far might perform well with so many features?

# %%
# Dimensionality Reduction
###########################

# This simply means reducing the dimension in your data with techniques such as:
# Factor Analysis, Principal Component Analysis, Backward Feature Elimination, SVD etc.

# Some inherent benefits of Dimensionality Reduction are:
   # It helps in data compressing and reducing the storage space required
   # It fastens the time required for performing same computations.
   # It can take care of multi-collinearity that improves the model performance
   # It is helpful in noise removal also 
   # Reducing the dimensions of data to 2D or 3D may allow us to plot and visualize it precisely. 
    
# Under the hood of Dimensionality reduction, PCA is 
# a feature extraction technique and not a feature elimination technique

# LDA is an example of supervised dimensionality reduction algorithm.

# %%
# What is PCA
#-------------#

# Principal component analysis is a method of extracting (not selecting) important 
# variables (in form of components) from a large set of variables available in a data set.
# It extracts low dimensional set of features from a high dimensional data set 
# with a motive to capture as much information as possible. If we did feature elimination,
# we could probably have lost a lot of information!

# It is always performed on a symmetric correlation or covariance matrix. 
# This means the matrix should be numeric and have standardized data.

# Remember, PCA can be applied only on numerical data. if the data has categorical 
# variables they must be converted to numerical

# %%
# When to use PCA
#----------------#

# Only when the answer to all the following questions is 'Yes'

1. # Do you want to reduce the number of variables, but aren’t able to 
    # identify variables to completely remove from consideration?
    
2. # Do you want to ensure your variables are independent of one another?
    
3. # Are you comfortable making your independent variables less interpretable?
# Out:
# 3.0

# %%
# Pictorial representation of PCA (from nlpca.org):
from IPython.display import Image
Image('pca_1.png')

# %%
# The image above shows the transformation of a high dimensional data (3 dimension)
# to low dimensional data (2 dimension) using PCA. Not to forget, each resultant 
# dimension is a linear combination of p normalized features

# %%
#------------------------------#
# What are Principal Components?
#------------------------------#

# A principal component is a normalized linear combination of 
# the original predictors in a data set.(In image above, PC1 and PC2)

# Let’s say we have a set of predictors as X¹, X²...,X^p
# First Principal component can be represented as:
# Z¹ = Φ¹¹X¹ + Φ²¹X² + Φ³¹X³ + .... +Φ^p¹X^p
# Second Principal component can be represented as:
# Z² = Φ¹²X¹ + Φ²²X² + Φ³²X³ + .... + Φ^p2X^p

# %%
# How PCA works?
Image('PCA_2.png')

# If the two components are uncorrelated, their directions should be orthogonal
# as you can see in the following figure

# Note that the directions of these components are identified in an unsupervised way 
# i.e. the response variable(Y) is not used to determine the component direction. 
# Therefore, it is an unsupervised approach.

# Since the original predictors may have different scales, it is required that
# normalized versions of original predictors are supplied to PCA
# Performing PCA on un-normalized variables will lead to insanely large loadings 
# for variables with high variance.

# %%
# -----------------------------------#
#       Steps of PCA Execution
# -----------------------------------#

# %%
# Step 1: Standardize or Normalize the data
#---------------------------------------------
# First step is to standardize or normalize the data so that each variable
# contributes equally to the analysis and PCA works properly. 
# You could calculate z-score of data points to Standardize them by doing (X-μ)/σ

# %%
# Step 2: Calculate Covariance Matrix
#--------------------------------------

# The aim of this step is to understand how the variables of the input data set 
# are varying from the mean with respect to each other,

# The covariance matrix is a p × p symmetric matrix (where p is the number of dimensions) 
# that has as entries, the covariances associated with all possible pairs of the initial variables. 

# For example, for a 3-dimensional data set with 3 variables x, y, and z, 
# the covariance matrix is a 3×3 matrix as shown below:
Image('covariance_matrix.png')

# Since the covariance of a variable with itself is its variance (Cov(a,a)=Var(a)), 
# in the main diagonal (Top left to bottom right) we actually have the variances of 
# each initial variable.

# Note that it’s actually the sign of the covariance that matters :
    # if positive then : the two variables increase or decrease together (correlated)
    # if negative then : One increases when the other decreases (Inversely correlated)

# %%
# Step 3: Calculate the eigenvalues and eigenvectors
#---------------------------------------------------

# Finding eigenvalues and eigenvectors is possible because it is a square matrix. 
# ƛ is an eigenvalue for a matrix A if it is a solution of the characteristic equation:
# det( ƛI - A ) = 0
# Where, I is the identity matrix of the same dimension as A which is a required 
# condition for the matrix subtraction as well in this case and ‘det’ is 
# the determinant of the matrix. For each eigenvalue ƛ, a corresponding 
# eigen-vector v, can be found by solving:
# ( ƛI - A )v = 0

# The eigenvectors and eigenvalues of a covariance (or correlation) matrix represent 
# the "core" of a PCA: The eigenvectors (principal components) determine the directions 
# of the new feature space, and the eigenvalues determine their magnitude. In other words, 
# the eigenvalues explain the variance of the data along the new feature axes.

# Intuitively, an eigenvector is a vector whose direction remains unchanged 
# when a linear transformation is applied to it.

# Geometrically speaking, principal components represent the directions of the 
# data that explain a maximal amount of variance, that is to say, the lines 
# that capture most information of the data.

# Eigenvectors and eigenvalues are the linear algebra concepts that we need
# to compute from the covariance matrix in order to determine the 
# principal components of the data.

# Principal components are new variables that are constructed as linear combinations 
# or mixtures of the initial variables. These combinations are done in such a way 
# that the new variables (i.e., principal components) are uncorrelated and most of the 
# information within the initial variables is squeezed or compressed into the first components. 

# So, the idea is 10-dimensional data gives you 10 principal components, but PCA 
# tries to put maximum possible information in the first component, then maximum
# remaining information in the second and so on, until having something like shown 
# in the scree plot below.
Image('variance_vs_components.png')

# %%
# Step 4: Choosing components and forming a feature vector:
#---------------------------------------------------------

# We order the eigenvalues from largest to smallest so that it gives us the 
# components in order of significance. 

# Here comes the dimensionality reduction part. 
# If we have a dataset with n variables, then we have the corresponding n eigenvalues 
# and eigenvectors. It turns out that the eigenvector corresponding to the highest 
# eigenvalue is the principal component of the dataset and it is our call as to 
# how many eigenvalues we choose to proceed our analysis with. 

# Next we form a feature vector which is a matrix of eigenvectors
# Feature Vector = (eig1, eig2) # As many eigen vectors as the number of PCs needed

# %%
# Step 5: Forming Principal Components:
#---------------------------------------------------------

# This is the final step where we actually form the principal components 
# using all the math we did till here. For the same, we take the transpose 
# of the feature vector and left-multiply it with the transpose of scaled 
#version of original dataset.

# NewData = (FeatureVector)T x (ScaledData)T
# T represents Transpose

# So, NewData is the Matrix consisting of the principal components

# %%
# Just to show how PCA works exactly
Image('PCA.gif')

# %%
# On a side note, Correlation vs Covariance?
#------------------------------------------#

# Correlation is when the change in one item may result in the change in 
# the another item. On the other hand, covariance is when two items vary together.

# In other words, a measure used to indicate the extent to which two random 
# variables change in tandem is known as covariance. A measure used to represent 
# how strongly two random variables are related known as correlation.

# Covariance is nothing but a measure of correlation. On the contrary, correlation 
# refers to the scaled form of covariance. Value of correlation takes place 
# between -1 and +1. Conversely, the value of covariance lies between -∞ and +∞.

# Correlation is dimensionless, i.e. it is a unit-free measure of the relationship 
# between variables. Unlike covariance, where the value is obtained by the product 
# of the units of the two variables.

# Covariance calculations provide information on whether variables have a positive 
# or negative relationship but cannot reveal the strength of the connection. 
# The magnitude of covariance may be skewed whenever the data set contains too 
# many significantly different values.

# Correlation is a special case of covariance which can be obtained 
# when the data is standardized. “Covariance” indicates the direction of the linear 
# relationship between variables. “Correlation” on the other hand measures both the 
# strength and direction of the linear relationship between two variables.
# What sets them apart is the fact that correlation values are standardized whereas, 
# covariance values are not. You can obtain the correlation coefficient of two variables 
# by dividing the covariance of these variables by the product of the standard 
# deviations of the same values

# Now, when it comes to making a choice, which is a better measure of the 
# relationship between two variables, correlation is preferred over covariance, 
# because it remains unaffected by the change in location and scale, and can 
# also be used to make a comparison between two pairs of variables.
Image('variance_covariance.png')

# %%
# Finally, the principal components are going to look like as shown below:
Image('First_PC.PNG')
# Linear combinations of features!
# Factor loadings (factor or component coefficients) : The factor loadings, 
# also called component loadings in PCA, are the correlation coefficients 

# Loadings (which should not be confused with eigenvectors) have the following properties:
    #Their sums of squares within each component are the 
       # eigenvalues (components' variances).
    #Loadings are coefficients in linear combination predicting a variable 
       #by the (standardized) components.

# %% [markdown]
# # PCA Example Use Case

# %%
# Import necessary libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
# Load 'iris' data
#url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
#df = pd.read_csv(url
#                 , names=['sepal length','sepal width','petal length','petal width','target'])

# %%
# Load iris data
from sklearn import datasets
iris = datasets.load_iris()
names=['sepal length','sepal width','petal length','petal width','target']
df = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= names)
df['target'] = df.target.replace(dict(enumerate(iris.target_names)))
print(df.head())
# Out:
#    sepal length  sepal width  petal length  petal width  target
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width  target
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Let us standardize the data (here it was not really needed, but let us do it)
features = ['sepal length', 'sepal width', 'petal length', 'petal width']

# Separate X and Y
x = df.loc[:, features].values
y = df.loc[:,['target']].values

# Use the StandardScaler to standardize the data
x = StandardScaler().fit_transform(x)

# take a look the transformed data
pd.DataFrame(data = x, columns = features).head()
# Out:
#    sepal length  sepal width  petal length  petal width
# 0     -0.900681     1.019004     -1.340227    -1.315444
# 1     -1.143017    -0.131979     -1.340227    -1.315444
# 2     -1.385353     0.328414     -1.397064    -1.315444
# 3     -1.506521     0.098217     -1.283389    -1.315444
# 4     -1.021849     1.249201     -1.340227    -1.315444

# %%
# Let us do PCA now. We have 4 variables, let us find 2 Principal Components
from sklearn.decomposition import PCA
# Create the PCA object model
pca = PCA(n_components=2)

# Use the PCA object model and get the Principal components for the given data
principalComponents = pca.fit_transform(x)

# Represent the Principal Components as DataFrame for ease of use
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

# take a look the principal components
principalDf.head(5)
# Out:
#    principal component 1  principal component 2
# 0              -2.264703               0.480027
# 1              -2.080961              -0.674134
# 2              -2.364229              -0.341908
# 3              -2.299384              -0.597395
# 4              -2.389842               0.646835

# %%
df[['target']].head()
# Out:
#    target
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
# Let us now create our new dataset with principal components and the target variable
finalDf = pd.concat([principalDf, df[['target']]], axis = 1)
finalDf.head(5)
# Out:
#    principal component 1  principal component 2  target
# 0              -2.264703               0.480027  setosa
# 1              -2.080961              -0.674134  setosa
# 2              -2.364229              -0.341908  setosa
# 3              -2.299384              -0.597395  setosa
# 4              -2.389842               0.646835  setosa

# %%
finalDf.head()
# Out:
#    principal component 1  principal component 2  target
# 0              -2.264703               0.480027  setosa
# 1              -2.080961              -0.674134  setosa
# 2              -2.364229              -0.341908  setosa
# 3              -2.299384              -0.597395  setosa
# 4              -2.389842               0.646835  setosa

# %%
plt.figure(figsize=(10,8))

plt.xlabel('Principal Component 1', fontsize = 12)
plt.ylabel('Principal Component 2', fontsize = 12)
plt.title('2 Component PCA', fontsize = 20)

targets = ['setosa', 'versicolor', 'virginica']
colors = ['r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['target'] == target
    plt.scatter(finalDf.loc[indicesToKeep, 'principal component 1'],
                finalDf.loc[indicesToKeep, 'principal component 2'],
                c = color,
                s = 50)
plt.legend(targets)
plt.grid()

# %%
# Let us see the explained variance
print(pca.explained_variance_ratio_)
# Out:
# [0.72962445 0.22850762]

# %%
# Notice that first principal component explained 72% variance
# and the second principal component explained 23% variance
# the total explained variance is more than 95%
pca.explained_variance_ratio_.sum()
# Out:
# 0.9581320720000164

# %%
# The third and fourth principal component contained the rest of the variance of the dataset.

# %%
# Interpreting Components
pca.components_
# Out:
# array([[ 0.52106591, -0.26934744,  0.5804131 ,  0.56485654],
#        [ 0.37741762,  0.92329566,  0.02449161,  0.06694199]])

# %%
components = pd.DataFrame(pca.components_, columns = features, index=['PC1', 'PC2'])
components
# Out:
#      sepal length  sepal width  petal length  petal width
# PC1      0.521066    -0.269347      0.580413     0.564857
# PC2      0.377418     0.923296      0.024492     0.066942

# %%
# Let us assume a scenario.
# You first use the PCA and then used the PCs to build a model
# When you get new data for prediction, how would you feed that to model?
# You first have to transform that pca.transform() and get the PC Values
# Then feed that to the model and get the predicted outcomes

# %%
# Some miscelleneous Points
#--------------------------#

# Obviously if you do PCA, some information is lost
# But is far better than ignoring some variables and loosing more information

# Using these principal components, one could run any ML algorithms as applicable

# Note: Partial least square (PLS) is a supervised alternative to PCA. 
# PLS assigns higher weight to variables which are strongly related to 
# response variable to determine principal components. 

#  Multicollinearity can be resolved by combining the highly correlated variables
# through principal component analysis.

# If the value of Mahalanobis Distance (MD) is squared, it is found that the 
# sum of squares of all non-zero principal components are equal to that of MD. 
# This is helpful to ascertain the right components based on the requirement in data analysis.

# %%
# Out:
# pandas.core.frame.DataFrame
