# %%
cd C:\Guru Jana Folder\StoreKING_DATA\ERP Extracts\4. Returns Master
# Out:
# C:\Guru Jana Folder\StoreKING_DATA\ERP Extracts\4. Returns Master

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is E463-CE57
#
#  Directory of C:\Guru Jana Folder\StoreKING_DATA\ERP Extracts\4. Returns Master
#
# 10-06-2020  00:39    <DIR>          .
# 10-06-2020  00:39    <DIR>          ..
# 05-06-2020  12:16            47,559 returns_1591339585910.csv
# 09-06-2020  15:59           131,080 returns_1591698257833.csv
#                2 File(s)        178,639 bytes
#                2 Dir(s)  45,074,550,784 bytes free

# %%
import pandas as pd

# %%
rtn = pd.read_csv('returns_1591698257833.csv', parse_dates=[2])
rtn.head()
# Out:
#             _id     _ReturnId _ReturnedDate     _InvoiceNo _InvoiceDate  \
# 0  RT2020010217  RT2020010217    2020-01-02  IN17100099192   2019-11-23
# 1  RT2020010218  RT2020010218    2020-01-02    IN181256196   2019-12-31
# 2  RT2020010319  RT2020010319    2020-01-03    IN181252301   2019-12-14
# 3  RT2020010320  RT2020010320    2020-01-03    IN341007057   2019-12-13
# 4  RT2020010321  RT2020010321    2020-01-03    IN181255711   2019-12-30
#
#    _WhId _SoldByState  _ReasonForReturn          _OrderId _FranchiseId  ...  \
# 0   WMF0    Karnataka   Dead On Arrival  OR20191122651972      F180848  ...
# 1   WMF1    Karnataka  Return To Origin  OR20191231705049      F100029  ...
# 2   WMF1    Karnataka  Product Mismatch  OR20191212679869      F207960  ...
# 3  WMF20          NaN  Product Mismatch  OR20191212680706      F142141  ...
# 4   WMF1    Karnataka  Return To Origin  OR20191229701324      F202813  ...
#
# ...

# %%
rtn.dtypes
# Out:
# _id                         object
# _ReturnId                   object
# _ReturnedDate       datetime64[ns]
# _InvoiceNo                  object
# _InvoiceDate                object
# _WhId                       object
# _SoldByState                object
# _ReasonForReturn            object
# _OrderId                    object
# _FranchiseId                object
# _ProductId                  object
# _ProductName                object
# _ProductMRP                float64
# _ProductPrice              float64
# _ReturnQty                   int64
# _ReturnValue               float64
# _TaxableValue              float64
# _IGSTRate                    int64
# _IGSTValue                 float64
# _CGSTRate                  float64
# _CGSTValue                 float64
# _SGSTRate                  float64
# _SGSTValue                 float64
# _intoWhDate                 object
# dtype: object

# %%
sel_rng = rtn[ (rtn._ReturnedDate > '2020-01-02') & (rtn._ReturnedDate < '2020-04-30')]

# %%
sel_rng.tail(6)
# Out:
#               _id     _ReturnId _ReturnedDate   _InvoiceNo _InvoiceDate  \
# 244  RT2020042925  RT2020042925    2020-04-29  IN351015841   2020-03-21
# 245  RT2020042926  RT2020042926    2020-04-29  IN351016416   2020-04-03
# 246  RT2020042927  RT2020042927    2020-04-29  IN351017426   2020-04-14
# 247  RT2020042928  RT2020042928    2020-04-29  IN351017428   2020-04-14
# 248  RT2020042929  RT2020042929    2020-04-29  IN351017763   2020-04-15
# 249  RT2020042930  RT2020042930    2020-04-29  IN181267578   2020-03-10
#
#      _WhId _SoldByState  _ReasonForReturn          _OrderId _FranchiseId  ...  \
# 244  WMF21          NaN           Service  OR20200317791581      F145014  ...
# 245  WMF21          NaN           Service  OR20200319793474      F185331  ...
# 246  WMF21          NaN           Service  OR20200329800428      F143855  ...
# 247  WMF21          NaN           Service  OR20200330800750      F143855  ...
# ...

# %%
sel_rng._ReturnedDate.dt.month_name()
# Out:
# 2      January
# 3      January
# 4      January
# 5      January
# 6      January
#         ...
# 245      April
# 246      April
# 247      April
# 248      April
# 249      April
# Name: _ReturnedDate, Length: 248, dtype: object

# %%
sel_rng.groupby('_FranchiseId').agg({'_ReturnQty': 'sum', '_ReturnValue':'sum'}).reset_index().sort_values('_ReturnValue',ascending=False)
# Out:
#    _FranchiseId  _ReturnQty  _ReturnValue
# 90      F214644         420    1918038.80
# 63      F206464        8076     198381.84
# 98      F215727        2248     104969.28
# 66      F207613        1692     101970.36
# 65      F207083        4428     100255.92
# ..          ...         ...           ...
# 1       F100569         522        185.20
# 31      F196336          24        184.10
# 71      F208633          24         21.84
# 50      F205056           1          1.00
# 75      F209269           1          1.00
#
# [103 rows x 3 columns]

# %%
cd C:\Guru Jana Folder\StoreKING_DATA\ERP Extracts\1. FOS Reports
# Out:
# C:\Guru Jana Folder\StoreKING_DATA\ERP Extracts\1. FOS Reports

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is E463-CE57
#
#  Directory of C:\Guru Jana Folder\StoreKING_DATA\ERP Extracts\1. FOS Reports
#
# 09-06-2020  16:01    <DIR>          .
# 09-06-2020  16:01    <DIR>          ..
# 29-05-2020  11:26        49,482,551 1. 1st Jan to  15th Jan.csv
# 29-05-2020  11:31        32,648,582 2. 15th Jan to 31st Jan.csv
# 29-05-2020  11:33        64,215,824 3. 1st Feb to 29th Feb.csv
# 29-05-2020  11:38        56,001,322 4. 1st Mar to 31st Mar.csv
# 09-06-2020  16:02       179,116,547 Consolidated FOS Report.csv
# 29-05-2020  12:04       107,254,742 Consolidated FOS Report.xlsx
#                6 File(s)    488,719,568 bytes
#                2 Dir(s)  45,048,221,696 bytes free

# %%
ovr = pd.read_csv('Consolidated FOS Report.csv', parse_dates=['OrderDate', 'InvoicedDate'])
ovr.head(25)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (1,38,39,57,58) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    orderCreateVia dealOfDay  isCommissionApporved  finalDiscount  \
# 0          OTHERS     False                 False            0.0
# 1          OTHERS     False                  True            0.0
# 2          OTHERS     False                  True            0.0
# 3          OTHERS     False                  True            0.0
# 4          OTHERS     False                  True            0.0
# 5          OTHERS     False                  True            0.0
# 6          OTHERS     False                  True            0.0
# 7          OTHERS     False                  True            0.0
# 8          OTHERS     False                  True            0.0
# ...

# %%
rtn.merge(ovr, how = 'inner', left_on = '_ProductId', right_on='ProductId')
# Out:
#                  _id     _ReturnId _ReturnedDate   _InvoiceNo _InvoiceDate  \
# 0       RT2020010218  RT2020010218    2020-01-02  IN181256196   2019-12-31
# 1       RT2020010218  RT2020010218    2020-01-02  IN181256196   2019-12-31
# 2       RT2020010218  RT2020010218    2020-01-02  IN181256196   2019-12-31
# 3       RT2020010218  RT2020010218    2020-01-02  IN181256196   2019-12-31
# 4       RT2020010218  RT2020010218    2020-01-02  IN181256196   2019-12-31
# ...              ...           ...           ...          ...          ...
# 663983   RT202006081   RT202006081    2020-06-08  IN401009566   2020-05-30
# 663984   RT202006081   RT202006081    2020-06-08  IN401009566   2020-05-30
# 663985   RT202006081   RT202006081    2020-06-08  IN401009566   2020-05-30
# 663986   RT202006081   RT202006081    2020-06-08  IN401009566   2020-05-30
# 663987   RT202006081   RT202006081    2020-06-08  IN401009566   2020-05-30
#
# ...
