# %%
import pandas as pd
import numpy as np
import os,re,datetime


pd.set_option('display.max_rows', 500)
pd.options.display.max_columns = 500
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', -1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   if __name__ == '__main__':

# %% [markdown]
# `Return date vs Invoice date vs _intoWh Date`

# %%
cd C:\Guru Jana Folder\StoreKING_DATA\ERP Extracts\4. Returns Master
# Out:
# C:\Guru Jana Folder\StoreKING_DATA\ERP Extracts\4. Returns Master

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is E463-CE57
#
#  Directory of C:\Guru Jana Folder\StoreKING_DATA\ERP Extracts\4. Returns Master
#
# 09-06-2020  16:00    <DIR>          .
# 09-06-2020  16:00    <DIR>          ..
# 05-06-2020  12:16            47,559 returns_1591339585910.csv
# 09-06-2020  15:59           131,080 returns_1591698257833.csv
#                2 File(s)        178,639 bytes
#                2 Dir(s)  10,035,937,280 bytes free

# %%
rtn_master = pd.read_csv('returns_1591698257833.csv', parse_dates= True)
rtn_master.head()
# Out:
#             _id     _ReturnId _ReturnedDate     _InvoiceNo _InvoiceDate  _WhId _SoldByState  _ReasonForReturn          _OrderId _FranchiseId _ProductId                                                    _ProductName  _ProductMRP  _ProductPrice  _ReturnQty  _ReturnValue  _TaxableValue  _IGSTRate  _IGSTValue  _CGSTRate  _CGSTValue  _SGSTRate  _SGSTValue          _intoWhDate
# 0  RT2020010217  RT2020010217  2020-01-02    IN17100099192  2019-11-23   WMF0   Karnataka    Dead On Arrival   OR20191122651972  F180848      PR15009    Nokia 105 Dual Sim (White)                                      1399.0       930.750000     1           930.750000    831.00         12         99.72       0.0        0.000       0.0        0.000       2020-01-02 10:52:39
# ...

# %%
dates_lookouts = rtn_master[['_OrderId','_ReturnedDate', '_InvoiceDate', '_intoWhDate']]

# %%
dates_lookouts.tail()
# Out:
#              _OrderId _ReturnedDate _InvoiceDate          _intoWhDate
# 514  OR20200603829080  2020-06-06    2020-06-03   2020-06-06 15:38:48
# 515  OR20200603829080  2020-06-06    2020-06-03   2020-06-06 15:38:49
# 516  OR20200530827319  2020-06-06    2020-06-02   2020-06-06 17:35:56
# 517  OR20200516822552  2020-06-08    2020-05-30   2020-06-08 15:30:56
# 518  OR20200519823374  2020-06-09    2020-05-21   2020-06-09 10:18:37

# %%
def date_spt(x):
	  return x.split(' ')[0]

# %%
dates_lookouts['_reached_warehse'] = dates_lookouts['_intoWhDate'].apply(lambda x: date_spt(x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dates_lookouts.dtypes
# Out:
# _OrderId            object
# _ReturnedDate       object
# _InvoiceDate        object
# _intoWhDate         object
# _reached_warehse    object
# dtype: object

# %%
dates_lookout_sel = dates_lookouts[dates_lookouts['_InvoiceDate'] >= "2020-01-01"]
dates_lookout_sel
# Out:
#              _OrderId _ReturnedDate _InvoiceDate          _intoWhDate _reached_warehse
# 10   OR20200104707755  2020-01-07    2020-01-04   2020-01-07 13:03:06  2020-01-07
# 11   OR20200103707671  2020-01-07    2020-01-04   2020-01-07 16:34:29  2020-01-07
# 12   OR20200103707671  2020-01-07    2020-01-04   2020-01-07 16:34:29  2020-01-07
# 13   OR20200107709881  2020-01-08    2020-01-07   2020-01-08 15:01:04  2020-01-08
# 14   OR20200107709872  2020-01-08    2020-01-07   2020-01-08 15:02:06  2020-01-08
# 15   OR20200107709869  2020-01-08    2020-01-07   2020-01-08 15:02:40  2020-01-08
# 16   OR20200107709865  2020-01-08    2020-01-07   2020-01-08 15:03:17  2020-01-08
# 17   OR20200107709875  2020-01-08    2020-01-07   2020-01-08 15:03:55  2020-01-08
# 18   OR20200107709873  2020-01-08    2020-01-07   2020-01-08 15:04:29  2020-01-08
# 19   OR20200107709870  2020-01-08    2020-01-07   2020-01-08 15:05:02  2020-01-08
# ...

# %%
dates_lookout_sel.head()
# Out:
#             _OrderId _ReturnedDate _InvoiceDate          _intoWhDate _reached_warehse
# 10  OR20200104707755  2020-01-07    2020-01-04   2020-01-07 13:03:06  2020-01-07
# 11  OR20200103707671  2020-01-07    2020-01-04   2020-01-07 16:34:29  2020-01-07
# 12  OR20200103707671  2020-01-07    2020-01-04   2020-01-07 16:34:29  2020-01-07
# 13  OR20200107709881  2020-01-08    2020-01-07   2020-01-08 15:01:04  2020-01-08
# 14  OR20200107709872  2020-01-08    2020-01-07   2020-01-08 15:02:06  2020-01-08

# %%
dates_lookout_sel.dtypes
# Out:
# _OrderId            object
# _ReturnedDate       object
# _InvoiceDate        object
# _intoWhDate         object
# _reached_warehse    object
# dtype: object

# %%
dates_lookout_sel.to_excel('date_checks.xlsx', index=False)

# %%
pwd
# Out:
# 'C:\\Guru Jana Folder\\StoreKING_DATA\\ERP Extracts\\4. Returns Master'

# %%
from datetime import datetime, date, time, timezone

# %%
# format_string = "%Y-%m-%d"

# %%
dates_lookout_sel['_ReturnedDate'] = pd.Series([pd.to_datetime(date) for date in dates_lookout_sel['_ReturnedDate']])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dates_lookout_sel['_ReturnedDate'].dt.month_name()
# Out:
# 10     January
# 11     January
# 12     January
# 13     January
# 14     January
# 15     January
# 16     January
# 17     January
# 18     January
# 19     January
# 20     January
# 21     January
# 22     January
# 23     January
# 24     January
# 25     January
# 26     January
# 27     January
# 39     February
# 40     February
# 42     February
# 43     February
# 44     February
# 45     February
# 46     February
# 51     February
# 52     February
# 53     February
# 54     February
# 55     February
# 56     February
# 57     February
# 58     February
# 59     February
# 60     February
# 61     February
# 62     February
# 63     February
# 64     February
# 65     February
# 67     February
# 68     February
# 69     February
# 70     February
# 71     February
# 72     February
# 73     February
# 74     February
# 75     February
# 76     February
# 77     February
# 78     February
# 79     February
# 80     February
# 82     February
# 83     February
# ...

# %%
dates_lookout_sel.dtypes
# Out:
# _OrderId            object
# _ReturnedDate       datetime64[ns]
# _InvoiceDate        object
# _intoWhDate         object
# _reached_warehse    object
# dtype: object

# %%
datetime.strptime("21/11/06 16:30", "%d/%m/%y %H:%M")
# Out:
# datetime.datetime(2006, 11, 21, 16, 30)

# %%
cd C:\Guru Jana Folder\StoreKING_DATA\ERP Extracts\4. Returns Master
# Out:
# C:\Guru Jana Folder\StoreKING_DATA\ERP Extracts\4. Returns Master

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is E463-CE57
#
#  Directory of C:\Guru Jana Folder\StoreKING_DATA\ERP Extracts\4. Returns Master
#
# 10-06-2020  00:39    <DIR>          .
# 10-06-2020  00:39    <DIR>          ..
# 05-06-2020  12:16            47,559 returns_1591339585910.csv
# 09-06-2020  15:59           131,080 returns_1591698257833.csv
#                2 File(s)        178,639 bytes
#                2 Dir(s)   7,852,863,488 bytes free

# %%
test = pd.read_csv('returns_1591698257833.csv', parse_dates=['_ReturnedDate', '_InvoiceDate', 	'_intoWhDate'])

# %%
test1 = test.loc[:, ['_OrderId','_ReturnedDate', '_InvoiceDate', '_intoWhDate'], ]

# %%
test1.dtypes
# Out:
# _OrderId         object
# _ReturnedDate    datetime64[ns]
# _InvoiceDate     datetime64[ns]
# _intoWhDate      datetime64[ns]
# dtype: object

# %%
test2 = test1[test1['_InvoiceDate'] >= "2020-01-01"]

# %%
test2['_ReturnedDate'].dt.month_name()
# Out:
# 10     January
# 11     January
# 12     January
# 13     January
# 14     January
# 15     January
# 16     January
# 17     January
# 18     January
# 19     January
# 20     January
# 21     January
# 22     January
# 23     January
# 24     January
# 25     January
# 26     January
# 27     January
# 39     January
# 40     January
# 42     January
# 43     January
# 44     January
# 45     January
# 46     January
# 51     January
# 52     January
# 53     January
# 54     January
# 55     January
# 56     January
# 57     January
# 58     January
# 59     January
# 60     January
# 61     January
# 62     January
# 63     January
# 64     February
# 65     February
# 67     February
# 68     February
# 69     February
# 70     February
# 71     February
# 72     February
# 73     February
# 74     February
# 75     February
# 76     February
# 77     February
# 78     February
# 79     February
# 80     February
# 82     February
# 83     February
# 84     February
# ...

# %%
text = """101   COM \t  Computers
205   MAT \t  Mathematics
189   ENG  \t  English"""

# %%
print(text)
# Out:
# 101   COM 	  Computers
# 205   MAT 	  Mathematics
# 189   ENG  	  English

# %%
# replace one or more spaces with single space
regex = re.compile('\s+')
print(regex.sub(' ', text))
# or
# print(re.sub('\s+', ' ', text))
# Out:
# 101 COM Computers 205 MAT Mathematics 189 ENG English

# %%
print(text)
# Out:
# 101   COM 	  Computers
# 205   MAT 	  Mathematics
# 189   ENG  	  English
