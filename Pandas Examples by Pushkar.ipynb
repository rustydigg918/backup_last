# %%
from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"

# %%
# %%time
import time
for _ in range(1000):
    time.sleep(0.01)
# Out:
# Wall time: 10.5 s

# %%
import numpy
# %timeit numpy.random.normal(size=100)
# Out:
# 5.72 µs ± 124 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %%writefile pythoncode.py

import numpy
def append_if_not_exists(arr, x):
    if x not in arr:
        arr.append(x)

def some_useless_slow_function():
    arr = list()
    for i in range(10000):
        x = numpy.random.randint(0, 10000)
        append_if_not_exists(arr, x)
# Out:
# Overwriting pythoncode.py

# %%
# %prun some_useless_slow_function()

# %%
# %pdb

def pick_and_take():
    picked = numpy.random.randint(0, 1000)
    raise NotImplementedError()

pick_and_take()
# Out:
# Automatic pdb calling has been turned ON
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-58-3c4361a68642> in <module>
#       5     raise NotImplementedError()
#       6
# ----> 7 pick_and_take()
#
# <ipython-input-58-3c4361a68642> in pick_and_take()
#       3 def pick_and_take():
#       4     picked = numpy.random.randint(0, 1000)
# ----> 5     raise NotImplementedError()
#       6
#       7 pick_and_take()
#
# NotImplementedError:
# > <ipython-input-58-3c4361a68642>(5)pick_and_take()
#       3 def pick_and_take():
#       4     picked = numpy.random.randint(0, 1000)
# ----> 5     raise NotImplementedError()
#       6
#       7 pick_and_take()
#
# ipdb> ee
# *** NameError: name 'ee' is not defined
# ipdb> pick_and_take()
# *** NotImplementedError

# %%
# %config InlineBackend.figure_format ='retina'

# %%
# !ls *.csv
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !pip list | grep pandas
# Out:
# 'grep' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# LaTeX

# %%
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
# !pip install jupyter_nbextensions_configurator
# !jupyter contrib nbextension install --user
# !jupyter nbextensions_configurator enable --user
# Out:
# ...
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x0000018B5648CA88>, 'Connection to 192.168.1.1 timed out. (connect timeout=15)')': /ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x0000018B5648F848>, 'Connection to 192.168.1.1 timed out. (connect timeout=15)')': /ipython-contrib/jupyter_contrib_nbextensions/tarball/master
# ...

# %%
# %%gitbash
# for i in {1..5}
# do
#    echo "i is $i"
# done
# Out:
# UsageError: Cell magic `%%gitbash` not found.

# %%
conda install -c r r-essentials
# Out:
# ...
#
# Note: you may need to restart the kernel to use updated packages.
# CondaHTTPError: HTTP 000 CONNECTION FAILED for url <https://conda.anaconda.org/r/win-64/current_repodata.json>
# Elapsed: -
#
# An HTTP error occurred when trying to retrieve this URL.
# HTTP errors are often intermittent, and a simple retry will get you on your way.
# 'https://conda.anaconda.org/r/win-64'

# %%
# !pip install jupyterthemes
# Out:
# ...
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x00000251A1CBAC48>, 'Connection to 192.168.1.1 timed out. (connect timeout=15)')': /simple/jupyterthemes/
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x00000251A1CBAF48>, 'Connection to 192.168.1.1 timed out. (connect timeout=15)')': /simple/jupyterthemes/
#   WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x00000251A1CBE188>, 'Connection to 192.168.1.1 timed out. (connect timeout=15)')': /simple/jupyterthemes/
# ...

# %%
# %pycat pythoncode.py

# %% [markdown]
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:%%!  %%HTML  %%SVG  %%bash  %%capture  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
# %autosave
# Out:
# UsageError: %autosave requires an integer, got ''

# %%
# !pip install bokeh

# %%
9
V
9

0

# %%
# %%html
# <marquee style='width: 60%; color: red;'><b>Guru & Jana!</b></marquee>

# %%
# %%html
# <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 450 400" width="200" height="200">
#   <rect x="80" y="60" width="250" height="250" rx="20" style="fill:red; stroke:black; fill-opacity:0.7" />
#   <rect x="180" y="110" width="250" height="250" rx="40" style="fill:blue; stroke:black; fill-opacity:0.5;" />
# </svg>
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 450 400" width="200" height="200">
#   <rect x="80" y="60" width="250" height="250" rx="20" style="fill:red; stroke:black; fill-opacity:0.7" />
#   <rect x="180" y="110" width="250" height="250" rx="40" style="fill:blue; stroke:black; fill-opacity:0.5;" />
# </svg>

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Fills and Alpha Example")
plt.show()

# %%
# %pprint
# Out:
# Pretty printing has been turned OFF

# %% [markdown]
# ## Loading data into Pandas

# %%
import os
#Setting working directory
path = 'C:\\Users\\pushkar\\datasets'
os.chdir(path)
print(os.getcwd())
# Out:
# C:\Users\pushkar\datasets

# %%
import pandas as pd

# %%
df = pd.read_csv('pokemon_data.csv')
# print(df.head(5))

df.head(9)

# df_xlsx = pd.read_excel('pokemon_data.xlsx')
# print(df_xlsx.head(3))

# df = pd.read_csv('pokemon_data.txt', delimiter='\t')
# print(df.head(5))

# df['HP']
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# ...

# %% [markdown]
# ## Reading Data in Pandas

# %%
#### Read Headers
# df.columns

## Read each Column
# print(df['Name'])
print(df['Name'][0:5])
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
type(df[['Name', 'Type 1', 'HP']])
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
## More than one column
# print(df[['Name', 'Type 1', 'HP']])

## Read Everything in the first row
# print(df.iloc[1])

## Read Multiple Rows
print(df.iloc[0:6])
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False

# %%
## Iter through the rows. VERY USEFUL
for index, row in df.iterrows():
    print(index, row)
    
## Iter the name and row value from the dataset    
# for index, row in df.iterrows():
#     print(index, row['Name'])    
    
## Finding specefic data from our dataset that isn't just the integer type but textual or numerical etc.    
# df.loc[df['Type 1'] == "Grass"]

## Read a specific location (R,C)
## Print the value from second row and first column
# print(df.iloc[2,1])
# Out:
# 0 #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
# 1 #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
# 2 #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object
# ...

# %%
# print(df['Name'][0:5])
df.loc[0:5,'Name']
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# 5               Charmeleon
# Name: Name, dtype: object

# %% [markdown]
# ## Sorting/Describing Data

# %%
# Analyse the given data
# df.describe()

# Sort data using two features
# df.sort_values(['Type 1', 'HP'], ascending = False)

# Sort by Name in descending order
df.sort_values('Name', ascending = False)

# df.sort_values(['Type 1', 'HP'], ascending=[1,0])

df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ## Making changes to the data

# %%
# df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

#  But that's not how we perform the task conventionally, So let's drop the Total column first
# df = df.drop(columns=['Total'])

# Use iloc function to locate it.
# df['Total'] = df.iloc[:, 4:10].sum(axis=1)

cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]]+cols[4:12]]

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Legendary  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison      False  45      49       49
# 1  2                Ivysaur  Grass  Poison      False  60      62       63
# 2  3               Venusaur  Grass  Poison      False  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison      False  80     100      123
# 4  4             Charmander   Fire     NaN      False  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
45+49+49+65+65+45
# Out:
# 318

# %% [markdown]
# ## Saving our Data (Exporting into Desired Format)

# %%
# df.to_csv('modified.csv', index=False)

# df.to_excel('modified.xlsx', index=False)

# df.to_csv('modified.txt', index=False, sep='\t')

# %% [markdown]
# ## Filtering Data

# %%
## Filter all the data having Grass as Type 1
# df.loc[df['Type 1'] == 'Grass']

## Filter data where Type 1 == "Grass" AND Type 2 == "Poison"
# df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]

## Filter data where Type 1 == "Grass" OR Type 2 == "Poison"
# df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Poison')]

# Filter More than two features
# df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

## put this value in a new varible
# new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

# %%
## Saving to crreate a dataframe
# new_df.to_csv('filtered.csv')

# new_df

## Eliminate the previous index numbers(it would simply add new index and by defult it turn the previous ones as a FEATURE)
# new_df.reset_index() 

## We can use 'drop' to remove the old indices
# new_df.reset_index(drop=True)

## Now we don't want to create a new dataframe in order to save space to we add inplace= true
# new_df.reset_index(drop=True, inplace=True)
# new_df

## Filter out all the names containing Mega
# df.loc[df['Name'].str.contains('Mega')]

## Filter out all the names that is NOT containing Mega
# df.loc[~df['Name'].str.contains('Mega')]

## Show Fire or Grass
# df.loc[df['Type 1'].str.contains('Fire|Grass')]

## This .str.contains method is so powerful coz it takes REGULAR EXPRESSION values as well and enhances the searchability
## And let's try and print giving the values of Type 1 in lowercase
import re
# df.loc[df['Type 1'].str.contains('fire|grass', flags = re.I, regex = True)]

## Let's get more fancy here and we want to show a Type 1 value which starts from Pi
# df.loc[df['Name'].str.contains('^pi[a-z]*', flags = re.I, regex = True)]

# %% [markdown]
# ## Conditional Changes

# %%
## Lets change the Type 1 value as Flamer where it has fire
# df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'

## Let's revert it back to the previous version
# df.loc[df['Type 1'] == 'Flamer', 'Type 1'] = 'Fire'

## You can also change the value of other features like this
# df.loc[df['Type 1'] == 'Fire', 'Legendary'] = 'True'


# we have messed up with the dataset we had, so let's revert it back
# df = pd.read_csv('modified.csv')
# df

## You can also change multiple parameters at a time like this...
# df.loc[df['Total'] > 500, ['Generation','Legendary']] = 'Test Value'
# df

## You can also change multiple parameters indivisually at a time like this...
# df.loc[df['Total'] > 500, ['Generation','Legendary']] = ['Test 1', 'Test 2']
# df

## Let's get to the previous checkpoint
# df = pd.read_csv('modified.csv')
# df.head()

# %% [markdown]
# ## Aggregate Statistics (Groupby)

# %%
df = pd.read_csv('modified.csv')
# df
### Apply Mean

## Look at averages of all the TYPE 1 Pokemon and sort it by Defense
# df.groupby(['Type 1']).mean().sort_values('Defense', ascending = False)

## Look at which has the highest Attack
# df.groupby(['Type 1']).mean().sort_values('Attack', ascending = False)

## Look at which has the highest HP
# df.groupby(['Type 1']).mean().sort_values('HP', ascending = False)

### Apply Sum Function
# ( Although in this case sum doesn't make any sense but we can do it)
# df.groupby(['Type 1']).sum().sort_values('HP', ascending = False)


### Count Function
# df.groupby(['Type 1']).count()

# But if you want a clear count value then...
# df['count'] = 1
# df.groupby(['Type 1']).count()['count']

# We could also group by multiple parameters
df['count'] = 1
df.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-d27371752417> in <module>
# ----> 1 df = pd.read_csv('modified.csv')
#       2 # df
#       3 ### Apply Mean
#       4
#       5 ## Look at averages of all the TYPE 1 Pokemon and sort it by Defense
#
# ...

# %% [markdown]
# ## Working with large amounts of data

# %%
# So if you're working with a dataset with a size of let's say 20gb, it's tought to load the whole thing in the memory.
## Let's look at the example
# for df in pd.read_csv('modified.csv', chunksize=5):
#     print("Chunk Df")
#     print(df)


new_df = pd.DataFrame(columns = df.columns)

for df in pd.read_csv('modified.csv', chunksize=5):
    results = df.groupby(['Type 1']).count()
    
    new_df = pd.concat([new_df, results], sort=True)
    print(new_df)
